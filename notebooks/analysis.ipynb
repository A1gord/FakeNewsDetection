# %% [markdown]
# # News Category Dataset - Analysis

# %% [markdown]
# You also can check this notebook here: https://www.kaggle.com/code/algord/news-category-dataset-analysis
# (New versions will be posted there more often.)

# %% [markdown]
# In this notebook, I will try to analyze news data. This is the preliminary stage of my scientific work on the prediction of the spread of news and information.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_json('../input/news-category-dataset/News_Category_Dataset_v2.json', lines=True)
df
# Out:
#              category                                           headline  \
# 0               CRIME  There Were 2 Mass Shootings In Texas Last Week...
# 1       ENTERTAINMENT  Will Smith Joins Diplo And Nicky Jam For The 2...
# 2       ENTERTAINMENT    Hugh Grant Marries For The First Time At Age 57
# 3       ENTERTAINMENT  Jim Carrey Blasts 'Castrato' Adam Schiff And D...
# 4       ENTERTAINMENT  Julianna Margulies Uses Donald Trump Poop Bags...
# ...               ...                                                ...
# 200848           TECH  RIM CEO Thorsten Heins' 'Significant' Plans Fo...
# 200849         SPORTS  Maria Sharapova Stunned By Victoria Azarenka I...
# 200850         SPORTS  Giants Over Patriots, Jets Over Colts Among  M...
# 200851         SPORTS  Aldon Smith Arrested: 49ers Linebacker Busted ...
# 200852         SPORTS  Dwight Howard Rips Teammates After Magic Loss ...
#
#                  authors                                               link  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200853 entries, 0 to 200852
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   category           200853 non-null  object
#  1   headline           200853 non-null  object
#  2   authors            200853 non-null  object
#  3   link               200853 non-null  object
#  4   short_description  200853 non-null  object
#  5   date               200853 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(5)
# memory usage: 9.2+ MB

# %% [markdown]
# So there are no Null values.

# %% [markdown]
# # Categories:

# %%
df['category'].value_counts()
# Out:
# POLITICS          32739
# WELLNESS          17827
# ENTERTAINMENT     16058
# TRAVEL             9887
# STYLE & BEAUTY     9649
# PARENTING          8677
# HEALTHY LIVING     6694
# QUEER VOICES       6314
# FOOD & DRINK       6226
# BUSINESS           5937
# COMEDY             5175
# SPORTS             4884
# BLACK VOICES       4528
# HOME & LIVING      4195
# PARENTS            3955
# THE WORLDPOST      3664
# WEDDINGS           3651
# WOMEN              3490
# IMPACT             3459
# DIVORCE            3426
# CRIME              3405
# MEDIA              2815
# WEIRD NEWS         2670
# GREEN              2622
# WORLDPOST          2579
# RELIGION           2556
# STYLE              2254
# SCIENCE            2178
# WORLD NEWS         2177
# TASTE              2096
# TECH               2082
# MONEY              1707
# ARTS               1509
# FIFTY              1401
# GOOD NEWS          1398
# ARTS & CULTURE     1339
# ENVIRONMENT        1323
# COLLEGE            1144
# ...

# %%
df['category'].value_counts().plot.bar(figsize=(20, 10));

# %% [markdown]
# # Date:

# %%
df['date'].hist(bins=100, figsize=(20, 10));

# %% [markdown]
# # Authors:

# %%
df['authors'].value_counts(ascending=False).reset_index()
# Out:
#                                                    index  authors
# 0                                                           36620
# 1                                              Lee Moran     2423
# 2                                             Ron Dicker     1913
# 3                                       Reuters, Reuters     1562
# 4                                               Ed Mazza     1322
# ...                                                  ...      ...
# 27988  Nicole C. Kear, ContributorAuthor, "Now I See ...        1
# 27989                               AMANDA LEE MYERS, AP        1
# 27990  Mario De Leo Winkler, ContributorPostdoctoral ...        1
# 27991  Kelly MacLean, ContributorStand up comic, actr...        1
# 27992  John Giacobbi, Contributor\nTales from the Int...        1
#
# [27993 rows x 2 columns]

# %% [markdown]
# We have 36620 articles without an author.

# %% [markdown]
# # Wordclouds:

# %%
from wordcloud import WordCloud

def make_wordcloud(text):
    wordcloud = WordCloud(width=1000, height=1000).generate(text)
    plt.figure(figsize = (10,10))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
txt = str(df['headline'].values).lower()
make_wordcloud(txt)

# %%
txt = str(df['short_description'].values).lower()
make_wordcloud(txt)
